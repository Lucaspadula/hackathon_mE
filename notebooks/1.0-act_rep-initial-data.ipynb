# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = os.path.join(os.path.expanduser("~"),"Documents\Lucas\MundoE\hackathon_mE\data\processed")
file_path = os.path.join(path, "ACTIVIDADES_REPARTIDOR_processed.csv")

# %%
df = pd.read_csv(file_path)
df
# Out:
#               ID_VISITA  ID_REPARTIDOR ID_HOJA_REPARTO  NUMERO_HOJA_REPARTO  \
# 0      1020180918092628             10           HOJA                 65996
# 1      1020180918092734             10           HOJA                 66011
# 2      1020180918130802             10           HOJA                 65996
# 3      1020180918130814             10           HOJA                 65996
# 4      1020180918131751             10           HOJA                 65996
# ...                 ...            ...             ...                  ...
# 48680   620220520194138              6           HOJA                 97651
# 48681  1020220520152238             10           HOJA                 97662
# 48682   620220520193707              6           HOJA                 97658
# 48683   620220520194101              6           HOJA                 97651
# 48684   620220520194112              6           HOJA                 97651
#
#         ID_CUENTA  FECHA_INICIO  HORA_INICIO  DURACION  CANT_FACT_TOTALES  \
# 0      0000009824      20180918        92628         0                  2
# 1      0000010656      20180918        92734         0                  1
# 2      0000008873      20180918       130802         0                  2
# 3      0000009824      20180918       130814         0                  2
# 4      0000009480      20180918       131751         0                  2
# ...           ...           ...          ...       ...                ...
# 48680  0000010930      20220520       194138         6                  2
# 48681  0000009913      20220520       152238         7                  2
# 48682  0000102035      20220520       193707       112                  1
# 48683  0000009869      20220520       194101         0                  1
# 48684  0000010142      20220520       194112        12                  2
#
#        CANT_FACT_ENTREGA_TOTAL  ...  CANT_ITEMS_NO_ENTREGADOS  \
# 0                            2  ...                       0.0
# 1                            1  ...                       0.0
# 2                            2  ...                       0.0
# 3                            2  ...                       0.0
# 4                            2  ...                       0.0
# ...                        ...  ...                       ...
# 48680                        2  ...                       0.0
# 48681                        2  ...                       0.0
# 48682                        1  ...                       0.0
# 48683                        1  ...                       0.0
# 48684                        2  ...                       0.0
#
#        CANT_COB_FACT_TOTALES  CANT_COB_FACT_COBRADAS  \
# 0                          0                       0
# 1                          1                       1
# 2                          2                       2
# 3                          0                       0
# 4                          2                       2
# ...                      ...                     ...
# 48680                      2                       2
# 48681                      2                       2
# 48682                      1                       1
# 48683                      1                       0
# 48684                      2                       2
#
#        CANT_COB_FACT_NO_COBRADAS  MONTO_TOTAL_DEUDA  MONTO_COBRADO  A_CREDITO  \
# 0                              0               0.00           0.00        0.0
# 1                              0            2173.03           0.00        1.0
# 2                              0            1631.56           0.00        1.0
# 3                              0               0.00           0.00        0.0
# 4                              0            2914.03           0.00        1.0
# ...                          ...                ...            ...        ...
# 48680                          0            7234.37        7234.37        0.0
# 48681                          0           12808.25       12808.25        0.0
# 48682                          0           15355.84       14940.28        0.0
# 48683                          1           27058.58           0.00        1.0
# 48684                          0           12309.42       12309.42        0.0
#
#        GPS_LATITUD  GPS_LONGITUD  GPS_PRECISION
# 0       -31.384962    -64.257537      10.000000
# 1       -31.384893    -64.257630      11.800000
# 2       -31.396538    -64.243463      10.000000
# 3       -31.396385    -64.243622       8.400000
# 4       -31.396610    -64.252255       6.500000
# ...            ...           ...            ...
# 48680   -31.320453    -64.316674       3.392317
# 48681   -31.406595    -64.223669       7.713821
# 48682     0.000000      0.000000       2.000000
# 48683     0.000000      0.000000       2.000000
# 48684     0.000000      0.000000       2.000000
#
# [48685 rows x 24 columns]

# %%
df.describe().T
# Out:
#                              count          mean           std           min  \
# ID_VISITA                  48685.0  1.862062e+15  7.307521e+15  1.202109e+14
# ID_REPARTIDOR              48685.0  4.355222e+00  3.186642e+00  1.000000e+00
# NUMERO_HOJA_REPARTO        48685.0  9.835407e+04  5.195292e+03  6.599400e+04
# FECHA_INICIO               48685.0  2.021968e+07  6.251001e+03  2.018092e+07
# HORA_INICIO                48685.0  1.363458e+05  5.339106e+04  4.000000e+00
# DURACION                   48685.0  3.261432e+01  7.260669e+02 -8.622100e+04
# CANT_FACT_TOTALES          48685.0  1.363007e+00  7.660797e-01  0.000000e+00
# CANT_FACT_ENTREGA_TOTAL    48685.0  1.020088e+00  9.048291e-01  0.000000e+00
# CANT_FACT_ENTREGA_PARCIAL  48685.0  3.882099e-03  6.251551e-02  0.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  48685.0  3.390367e-01  6.779486e-01  0.000000e+00
# CANT_ITEMS_TOTALES         48685.0  8.658618e+01  2.024028e+02  0.000000e+00
# CANT_ITEMS_ENTREGADOS      48685.0  6.937377e+01  1.921371e+02  0.000000e+00
# CANT_ITEMS_NO_ENTREGADOS   48685.0  1.721241e+01  8.013261e+01  0.000000e+00
# CANT_COB_FACT_TOTALES      48685.0  1.237506e+00  9.400604e-01  0.000000e+00
# CANT_COB_FACT_COBRADAS     48685.0  8.028551e-01  7.932709e-01  0.000000e+00
# CANT_COB_FACT_NO_COBRADAS  48685.0  4.346513e-01  9.535182e-01 -1.000000e+00
# MONTO_TOTAL_DEUDA          48685.0  1.039065e+04  2.046599e+04  0.000000e+00
# MONTO_COBRADO              48685.0  3.652170e+03  7.604780e+03  0.000000e+00
# A_CREDITO                  48358.0  4.872203e-01  4.998418e-01  0.000000e+00
# GPS_LATITUD                48685.0 -2.092287e+01  1.479124e+01 -3.152307e+01
# GPS_LONGITUD               48685.0 -4.283139e+01  3.027923e+01 -6.450169e+01
# GPS_PRECISION              48685.0  6.920096e+00  1.941356e+01  0.000000e+00
#
#                                     25%           50%           75%  \
# ID_VISITA                  3.202204e+14  6.202204e+14  1.020221e+15
# ID_REPARTIDOR              1.000000e+00  4.000000e+00  6.000000e+00
# NUMERO_HOJA_REPARTO        9.730200e+04  9.907100e+04  1.009120e+05
# FECHA_INICIO               2.022051e+07  2.022072e+07  2.022101e+07
# HORA_INICIO                1.016540e+05  1.347090e+05  1.732450e+05
# DURACION                   0.000000e+00  0.000000e+00  8.000000e+00
# CANT_FACT_TOTALES          1.000000e+00  1.000000e+00  2.000000e+00
# CANT_FACT_ENTREGA_TOTAL    0.000000e+00  1.000000e+00  1.000000e+00
# CANT_FACT_ENTREGA_PARCIAL  0.000000e+00  0.000000e+00  0.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  0.000000e+00  0.000000e+00  1.000000e+00
# CANT_ITEMS_TOTALES         1.400000e+01  3.700000e+01  8.800000e+01
# CANT_ITEMS_ENTREGADOS      0.000000e+00  2.200000e+01  6.800000e+01
# CANT_ITEMS_NO_ENTREGADOS   0.000000e+00  0.000000e+00  0.000000e+00
# CANT_COB_FACT_TOTALES      1.000000e+00  1.000000e+00  1.000000e+00
# CANT_COB_FACT_COBRADAS     0.000000e+00  1.000000e+00  1.000000e+00
# CANT_COB_FACT_NO_COBRADAS  0.000000e+00  0.000000e+00  1.000000e+00
# MONTO_TOTAL_DEUDA          2.404270e+03  5.304420e+03  1.127136e+04
# MONTO_COBRADO              0.000000e+00  0.000000e+00  4.774330e+03
# A_CREDITO                  0.000000e+00  0.000000e+00  1.000000e+00
# GPS_LATITUD               -3.139694e+01 -3.134947e+01  0.000000e+00
# GPS_LONGITUD              -6.423772e+01 -6.420811e+01  0.000000e+00
# GPS_PRECISION              1.448648e+00  2.600000e+00  7.504000e+00
#
#                                     max
# ID_VISITA                  1.020221e+17
# ID_REPARTIDOR              1.000000e+01
# NUMERO_HOJA_REPARTO        1.032620e+05
# FECHA_INICIO               2.023012e+07
# HORA_INICIO                2.359340e+05
# DURACION                   4.493600e+04
# CANT_FACT_TOTALES          2.700000e+01
# CANT_FACT_ENTREGA_TOTAL    2.700000e+01
# CANT_FACT_ENTREGA_PARCIAL  2.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  1.000000e+01
# CANT_ITEMS_TOTALES         9.553000e+03
# CANT_ITEMS_ENTREGADOS      9.553000e+03
# CANT_ITEMS_NO_ENTREGADOS   5.133000e+03
# CANT_COB_FACT_TOTALES      2.700000e+01
# CANT_COB_FACT_COBRADAS     1.500000e+01
# CANT_COB_FACT_NO_COBRADAS  2.700000e+01
# MONTO_TOTAL_DEUDA          1.264982e+06
# MONTO_COBRADO              2.645593e+05
# A_CREDITO                  1.000000e+00
# GPS_LATITUD                0.000000e+00
# GPS_LONGITUD               0.000000e+00
# GPS_PRECISION              9.611807e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48685 entries, 0 to 48684
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID_VISITA                  48685 non-null  int64
#  1   ID_REPARTIDOR              48685 non-null  int64
#  2   ID_HOJA_REPARTO            48685 non-null  object
#  3   NUMERO_HOJA_REPARTO        48685 non-null  int64
#  4   ID_CUENTA                  48685 non-null  object
#  5   FECHA_INICIO               48685 non-null  int64
#  6   HORA_INICIO                48685 non-null  int64
#  7   DURACION                   48685 non-null  int64
#  8   CANT_FACT_TOTALES          48685 non-null  int64
#  9   CANT_FACT_ENTREGA_TOTAL    48685 non-null  int64
#  10  CANT_FACT_ENTREGA_PARCIAL  48685 non-null  int64
#  11  CANT_FACT_ENTREGA_MOTIVOS  48685 non-null  int64
#  12  CANT_ITEMS_TOTALES         48685 non-null  float64
#  13  CANT_ITEMS_ENTREGADOS      48685 non-null  float64
#  14  CANT_ITEMS_NO_ENTREGADOS   48685 non-null  float64
#  15  CANT_COB_FACT_TOTALES      48685 non-null  int64
#  16  CANT_COB_FACT_COBRADAS     48685 non-null  int64
#  17  CANT_COB_FACT_NO_COBRADAS  48685 non-null  int64
#  18  MONTO_TOTAL_DEUDA          48685 non-null  float64
#  19  MONTO_COBRADO              48685 non-null  float64
#  20  A_CREDITO                  48358 non-null  float64
#  21  GPS_LATITUD                48685 non-null  float64
#  22  GPS_LONGITUD               48685 non-null  float64
#  23  GPS_PRECISION              48685 non-null  float64
# dtypes: float64(9), int64(13), object(2)
# memory usage: 8.9+ MB

# %%
#Detectar si tiene valores NULL o Vacios
def detectar_null_vacio(df):
    valores_vacion_null = {}
    for column in df.columns:
        nulls = df[column].isnull().sum()
        empties = (df[column]== '').sum()
        total = nulls + empties
        if total > 0:
            valores_vacion_null[column] = total
            
    return valores_vacion_null
    

resultado = detectar_null_vacio(df)

if resultado:
    for campo,cantidad in  resultado.items():
        print(f'El campo {campo} tiene {cantidad} valores NULL o vacios')
else:
    print('No hay campos NULL o vacios ')
# Out:
# No hay campos NULL o vacios

# %%
df['A_CREDITO'] = df['A_CREDITO'].fillna(0)

# %%
df.hist(bins=5,figsize=(30,40))
plt.show()

# %%
# Agrupar por repartidor y calcular el monto promedio cobrado y el total de facturas
df_grouped = df.groupby('ID_REPARTIDOR').agg({
    'MONTO_COBRADO': 'sum'
}).reset_index()


# Gráfico
plt.figure(figsize=(20, 8))
ax = sns.barplot(data=df_grouped,
                    y='ID_REPARTIDOR',
                    x='MONTO_COBRADO'
                    )

# Etiquetas del gráfico
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')

ax.set(xlabel='MONTO COBRADO ', ylabel='REPARTIDOR', title='Monto total Cobrado y Cantidad de Facturas')

plt.tight_layout()

# %%
df.groupby('ID_REPARTIDOR')['MONTO_COBRADO'].sum().reset_index()
# Out:
#    ID_REPARTIDOR  MONTO_COBRADO
# 0              1    56656496.83
# 1              3    44155897.89
# 2              4    13960978.40
# 3              5     5944204.56
# 4              6    36347236.00
# 5             10    20741063.19

# %%
df.describe().T
# Out:
#                              count          mean           std           min  \
# ID_VISITA                  48685.0  1.862062e+15  7.307521e+15  1.202109e+14
# ID_REPARTIDOR              48685.0  4.355222e+00  3.186642e+00  1.000000e+00
# NUMERO_HOJA_REPARTO        48685.0  9.835407e+04  5.195292e+03  6.599400e+04
# FECHA_INICIO               48685.0  2.021968e+07  6.251001e+03  2.018092e+07
# HORA_INICIO                48685.0  1.363458e+05  5.339106e+04  4.000000e+00
# DURACION                   48685.0  3.261432e+01  7.260669e+02 -8.622100e+04
# CANT_FACT_TOTALES          48685.0  1.363007e+00  7.660797e-01  0.000000e+00
# CANT_FACT_ENTREGA_TOTAL    48685.0  1.020088e+00  9.048291e-01  0.000000e+00
# CANT_FACT_ENTREGA_PARCIAL  48685.0  3.882099e-03  6.251551e-02  0.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  48685.0  3.390367e-01  6.779486e-01  0.000000e+00
# CANT_ITEMS_TOTALES         48685.0  8.658618e+01  2.024028e+02  0.000000e+00
# CANT_ITEMS_ENTREGADOS      48685.0  6.937377e+01  1.921371e+02  0.000000e+00
# CANT_ITEMS_NO_ENTREGADOS   48685.0  1.721241e+01  8.013261e+01  0.000000e+00
# CANT_COB_FACT_TOTALES      48685.0  1.237506e+00  9.400604e-01  0.000000e+00
# CANT_COB_FACT_COBRADAS     48685.0  8.028551e-01  7.932709e-01  0.000000e+00
# CANT_COB_FACT_NO_COBRADAS  48685.0  4.346513e-01  9.535182e-01 -1.000000e+00
# MONTO_TOTAL_DEUDA          48685.0  1.039065e+04  2.046599e+04  0.000000e+00
# MONTO_COBRADO              48685.0  3.652170e+03  7.604780e+03  0.000000e+00
# A_CREDITO                  48358.0  4.872203e-01  4.998418e-01  0.000000e+00
# GPS_LATITUD                48685.0 -2.092287e+01  1.479124e+01 -3.152307e+01
# GPS_LONGITUD               48685.0 -4.283139e+01  3.027923e+01 -6.450169e+01
# GPS_PRECISION              48685.0  6.920096e+00  1.941356e+01  0.000000e+00
#
#                                     25%           50%           75%  \
# ID_VISITA                  3.202204e+14  6.202204e+14  1.020221e+15
# ID_REPARTIDOR              1.000000e+00  4.000000e+00  6.000000e+00
# NUMERO_HOJA_REPARTO        9.730200e+04  9.907100e+04  1.009120e+05
# FECHA_INICIO               2.022051e+07  2.022072e+07  2.022101e+07
# HORA_INICIO                1.016540e+05  1.347090e+05  1.732450e+05
# DURACION                   0.000000e+00  0.000000e+00  8.000000e+00
# CANT_FACT_TOTALES          1.000000e+00  1.000000e+00  2.000000e+00
# CANT_FACT_ENTREGA_TOTAL    0.000000e+00  1.000000e+00  1.000000e+00
# CANT_FACT_ENTREGA_PARCIAL  0.000000e+00  0.000000e+00  0.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  0.000000e+00  0.000000e+00  1.000000e+00
# CANT_ITEMS_TOTALES         1.400000e+01  3.700000e+01  8.800000e+01
# CANT_ITEMS_ENTREGADOS      0.000000e+00  2.200000e+01  6.800000e+01
# CANT_ITEMS_NO_ENTREGADOS   0.000000e+00  0.000000e+00  0.000000e+00
# CANT_COB_FACT_TOTALES      1.000000e+00  1.000000e+00  1.000000e+00
# CANT_COB_FACT_COBRADAS     0.000000e+00  1.000000e+00  1.000000e+00
# CANT_COB_FACT_NO_COBRADAS  0.000000e+00  0.000000e+00  1.000000e+00
# MONTO_TOTAL_DEUDA          2.404270e+03  5.304420e+03  1.127136e+04
# MONTO_COBRADO              0.000000e+00  0.000000e+00  4.774330e+03
# A_CREDITO                  0.000000e+00  0.000000e+00  1.000000e+00
# GPS_LATITUD               -3.139694e+01 -3.134947e+01  0.000000e+00
# GPS_LONGITUD              -6.423772e+01 -6.420811e+01  0.000000e+00
# GPS_PRECISION              1.448648e+00  2.600000e+00  7.504000e+00
#
#                                     max
# ID_VISITA                  1.020221e+17
# ID_REPARTIDOR              1.000000e+01
# NUMERO_HOJA_REPARTO        1.032620e+05
# FECHA_INICIO               2.023012e+07
# HORA_INICIO                2.359340e+05
# DURACION                   4.493600e+04
# CANT_FACT_TOTALES          2.700000e+01
# CANT_FACT_ENTREGA_TOTAL    2.700000e+01
# CANT_FACT_ENTREGA_PARCIAL  2.000000e+00
# CANT_FACT_ENTREGA_MOTIVOS  1.000000e+01
# CANT_ITEMS_TOTALES         9.553000e+03
# CANT_ITEMS_ENTREGADOS      9.553000e+03
# CANT_ITEMS_NO_ENTREGADOS   5.133000e+03
# CANT_COB_FACT_TOTALES      2.700000e+01
# CANT_COB_FACT_COBRADAS     1.500000e+01
# CANT_COB_FACT_NO_COBRADAS  2.700000e+01
# MONTO_TOTAL_DEUDA          1.264982e+06
# MONTO_COBRADO              2.645593e+05
# A_CREDITO                  1.000000e+00
# GPS_LATITUD                0.000000e+00
# GPS_LONGITUD               0.000000e+00
# GPS_PRECISION              9.611807e+02

# %%
df['FECHA_INICIO'] = pd.to_datetime(df['FECHA_INICIO'], format= '%Y%m%d')

df['YEAR'] = df['FECHA_INICIO'].dt.year

df
# Out:
#               ID_VISITA  ID_REPARTIDOR ID_HOJA_REPARTO  NUMERO_HOJA_REPARTO  \
# 0      1020180918092628             10           HOJA                 65996
# 1      1020180918092734             10           HOJA                 66011
# 2      1020180918130802             10           HOJA                 65996
# 3      1020180918130814             10           HOJA                 65996
# 4      1020180918131751             10           HOJA                 65996
# ...                 ...            ...             ...                  ...
# 48680   620220520194138              6           HOJA                 97651
# 48681  1020220520152238             10           HOJA                 97662
# 48682   620220520193707              6           HOJA                 97658
# 48683   620220520194101              6           HOJA                 97651
# 48684   620220520194112              6           HOJA                 97651
#
#         ID_CUENTA FECHA_INICIO  HORA_INICIO  DURACION  CANT_FACT_TOTALES  \
# 0      0000009824   2018-09-18        92628         0                  2
# 1      0000010656   2018-09-18        92734         0                  1
# 2      0000008873   2018-09-18       130802         0                  2
# 3      0000009824   2018-09-18       130814         0                  2
# 4      0000009480   2018-09-18       131751         0                  2
# ...           ...          ...          ...       ...                ...
# 48680  0000010930   2022-05-20       194138         6                  2
# 48681  0000009913   2022-05-20       152238         7                  2
# 48682  0000102035   2022-05-20       193707       112                  1
# 48683  0000009869   2022-05-20       194101         0                  1
# 48684  0000010142   2022-05-20       194112        12                  2
#
#        CANT_FACT_ENTREGA_TOTAL  ...  CANT_COB_FACT_TOTALES  \
# 0                            2  ...                      0
# 1                            1  ...                      1
# 2                            2  ...                      2
# 3                            2  ...                      0
# 4                            2  ...                      2
# ...                        ...  ...                    ...
# 48680                        2  ...                      2
# 48681                        2  ...                      2
# 48682                        1  ...                      1
# 48683                        1  ...                      1
# 48684                        2  ...                      2
#
#        CANT_COB_FACT_COBRADAS  CANT_COB_FACT_NO_COBRADAS  MONTO_TOTAL_DEUDA  \
# 0                           0                          0               0.00
# 1                           1                          0            2173.03
# 2                           2                          0            1631.56
# 3                           0                          0               0.00
# 4                           2                          0            2914.03
# ...                       ...                        ...                ...
# 48680                       2                          0            7234.37
# 48681                       2                          0           12808.25
# 48682                       1                          0           15355.84
# 48683                       0                          1           27058.58
# 48684                       2                          0           12309.42
#
#        MONTO_COBRADO  A_CREDITO  GPS_LATITUD  GPS_LONGITUD  GPS_PRECISION  \
# 0               0.00        0.0   -31.384962    -64.257537      10.000000
# 1               0.00        1.0   -31.384893    -64.257630      11.800000
# 2               0.00        1.0   -31.396538    -64.243463      10.000000
# 3               0.00        0.0   -31.396385    -64.243622       8.400000
# 4               0.00        1.0   -31.396610    -64.252255       6.500000
# ...              ...        ...          ...           ...            ...
# 48680        7234.37        0.0   -31.320453    -64.316674       3.392317
# 48681       12808.25        0.0   -31.406595    -64.223669       7.713821
# 48682       14940.28        0.0     0.000000      0.000000       2.000000
# 48683           0.00        1.0     0.000000      0.000000       2.000000
# 48684       12309.42        0.0     0.000000      0.000000       2.000000
#
#        YEAR
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
# ...     ...
# 48680  2022
# 48681  2022
# 48682  2022
# 48683  2022
# 48684  2022
#
# [48685 rows x 25 columns]

# %%
df['YEAR'].unique()
# Out:
# array([2018, 2023, 2022, 2021])

# %%
years = [2023, 2022, 2021,2018]

for year in years:
    plt.figure(figsize=(15,5))
    ax = sns.barplot(
        x = df[df['YEAR'] == year].groupby('ID_REPARTIDOR')['MONTO_COBRADO'].sum().values,
        y = df[df['YEAR'] == year].groupby('ID_REPARTIDOR')['MONTO_COBRADO'].sum().index
    )
    ax.set(xlabel= 'MONTO COBRADO', ylabel= 'REPARTIDOR', title=f'MONTO COBRADO EN EL AÑO {year}')
    plt.bar_label(ax.containers[0],size = 10)
    plt.tight_layout
    plt.show()

# %%
df.describe().T
# Out:
#                              count                           mean  \
# ID_VISITA                  48685.0            1862061511215558.75
# ID_REPARTIDOR              48685.0                       4.355222
# NUMERO_HOJA_REPARTO        48685.0                   98354.073164
# FECHA_INICIO                 48685  2022-06-20 06:20:02.785252352
# HORA_INICIO                48685.0                  136345.843977
# DURACION                   48685.0                      32.614317
# CANT_FACT_TOTALES          48685.0                       1.363007
# CANT_FACT_ENTREGA_TOTAL    48685.0                       1.020088
# CANT_FACT_ENTREGA_PARCIAL  48685.0                       0.003882
# CANT_FACT_ENTREGA_MOTIVOS  48685.0                       0.339037
# CANT_ITEMS_TOTALES         48685.0                      86.586176
# CANT_ITEMS_ENTREGADOS      48685.0                       69.37377
# CANT_ITEMS_NO_ENTREGADOS   48685.0                      17.212406
# CANT_COB_FACT_TOTALES      48685.0                       1.237506
# CANT_COB_FACT_COBRADAS     48685.0                       0.802855
# CANT_COB_FACT_NO_COBRADAS  48685.0                       0.434651
# MONTO_TOTAL_DEUDA          48685.0                   10390.646906
# MONTO_COBRADO              48685.0                    3652.169598
# A_CREDITO                  48358.0                        0.48722
# GPS_LATITUD                48685.0                     -20.922873
# GPS_LONGITUD               48685.0                     -42.831389
# GPS_PRECISION              48685.0                       6.920096
# YEAR                       48685.0                    2021.892513
#
#                                            min                  25%  \
# ID_VISITA                    120210923083707.0    320220413163230.0
# ID_REPARTIDOR                              1.0                  1.0
# NUMERO_HOJA_REPARTO                    65994.0              97302.0
# FECHA_INICIO               2018-09-18 00:00:00  2022-05-10 00:00:00
# HORA_INICIO                                4.0             101654.0
# DURACION                              -86221.0                  0.0
# CANT_FACT_TOTALES                          0.0                  1.0
# CANT_FACT_ENTREGA_TOTAL                    0.0                  0.0
# CANT_FACT_ENTREGA_PARCIAL                  0.0                  0.0
# CANT_FACT_ENTREGA_MOTIVOS                  0.0                  0.0
# CANT_ITEMS_TOTALES                         0.0                 14.0
# CANT_ITEMS_ENTREGADOS                      0.0                  0.0
# CANT_ITEMS_NO_ENTREGADOS                   0.0                  0.0
# CANT_COB_FACT_TOTALES                      0.0                  1.0
# CANT_COB_FACT_COBRADAS                     0.0                  0.0
# CANT_COB_FACT_NO_COBRADAS                 -1.0                  0.0
# MONTO_TOTAL_DEUDA                          0.0              2404.27
# MONTO_COBRADO                              0.0                  0.0
# A_CREDITO                                  0.0                  0.0
# GPS_LATITUD                         -31.523066           -31.396936
# GPS_LONGITUD                        -64.501693            -64.23772
# GPS_PRECISION                              0.0             1.448648
# YEAR                                    2018.0               2022.0
#
#                                            50%                  75%  \
# ID_VISITA                    620220413152054.0   1020220923100540.0
# ID_REPARTIDOR                              4.0                  6.0
# NUMERO_HOJA_REPARTO                    99071.0             100912.0
# FECHA_INICIO               2022-07-20 00:00:00  2022-10-07 00:00:00
# HORA_INICIO                           134709.0             173245.0
# DURACION                                   0.0                  8.0
# CANT_FACT_TOTALES                          1.0                  2.0
# CANT_FACT_ENTREGA_TOTAL                    1.0                  1.0
# CANT_FACT_ENTREGA_PARCIAL                  0.0                  0.0
# CANT_FACT_ENTREGA_MOTIVOS                  0.0                  1.0
# CANT_ITEMS_TOTALES                        37.0                 88.0
# CANT_ITEMS_ENTREGADOS                     22.0                 68.0
# CANT_ITEMS_NO_ENTREGADOS                   0.0                  0.0
# CANT_COB_FACT_TOTALES                      1.0                  1.0
# CANT_COB_FACT_COBRADAS                     1.0                  1.0
# CANT_COB_FACT_NO_COBRADAS                  0.0                  1.0
# MONTO_TOTAL_DEUDA                      5304.42             11271.36
# MONTO_COBRADO                              0.0              4774.33
# A_CREDITO                                  0.0                  1.0
# GPS_LATITUD                         -31.349472                  0.0
# GPS_LONGITUD                        -64.208111                  0.0
# GPS_PRECISION                              2.6                7.504
# YEAR                                    2022.0               2022.0
#
#                                             max                 std
# ID_VISITA                  102022112409102304.0  7307521216379250.0
# ID_REPARTIDOR                              10.0            3.186642
# NUMERO_HOJA_REPARTO                    103262.0         5195.291934
# FECHA_INICIO                2023-01-17 00:00:00                 NaN
# HORA_INICIO                            235934.0        53391.057318
# DURACION                                44936.0          726.066933
# CANT_FACT_TOTALES                          27.0             0.76608
# CANT_FACT_ENTREGA_TOTAL                    27.0            0.904829
# CANT_FACT_ENTREGA_PARCIAL                   2.0            0.062516
# CANT_FACT_ENTREGA_MOTIVOS                  10.0            0.677949
# CANT_ITEMS_TOTALES                       9553.0          202.402796
# CANT_ITEMS_ENTREGADOS                    9553.0          192.137115
# CANT_ITEMS_NO_ENTREGADOS                 5133.0           80.132613
# CANT_COB_FACT_TOTALES                      27.0             0.94006
# CANT_COB_FACT_COBRADAS                     15.0            0.793271
# CANT_COB_FACT_NO_COBRADAS                  27.0            0.953518
# MONTO_TOTAL_DEUDA                    1264982.46        20465.987029
# MONTO_COBRADO                         264559.35         7604.779749
# A_CREDITO                                   1.0            0.499842
# GPS_LATITUD                                 0.0           14.791239
# GPS_LONGITUD                                0.0           30.279226
# GPS_PRECISION                        961.180725           19.413559
# YEAR                                     2023.0            0.633379

# %%
for year in years:
    plt.figure(figsize=(15,5))
    ax = sns.barplot(
        x = df[df['YEAR'] == year].groupby('ID_REPARTIDOR')['CANT_FACT_TOTALES'].sum().index,
        y = df[df['YEAR'] == year].groupby('ID_REPARTIDOR')['CANT_FACT_TOTALES'].sum().values
    )
    ax.set(xlabel= 'REPARTIDOR', ylabel= 'CANTIDAD DE FACTURAS', title=f'CANTIDAD DE FACTURAS EN EL AÑO {year}')
    plt.bar_label(ax.containers[0],size = 10)
    plt.tight_layout
    plt.show()

# %%
for year in years:
    plt.figure(figsize=(15,5))
    
    # Filtrar datos por año
    df_filtered = df[df['YEAR'] == year]
    
    # Agrupar y sumar las cantidades
    grouped_data = df_filtered.groupby('ID_REPARTIDOR').agg({
        'CANT_FACT_TOTALES': 'sum',
        'CANT_FACT_ENTREGA_TOTAL': 'sum'
    }).reset_index()
    
    # Crear gráfico
    ax = sns.barplot(
        x='ID_REPARTIDOR',
        y='CANT_FACT_TOTALES',
        data=grouped_data,
        color='black',
        label='Facturas Totales'
    )
    
    # Agregar barras para la cantidad de facturas entregadas
    ax2 = sns.barplot(
        x='ID_REPARTIDOR',
        y='CANT_FACT_ENTREGA_TOTAL',
        data=grouped_data,
        color='orange',
        label='Facturas Entregadas',
        alpha=0.6  # Ajusta la transparencia para ver ambas barras claramente
    )
    
    # Etiquetas al lado de las barras
    for container in ax.containers:
        for bar in container:
            height = bar.get_height()
            ax.text(
                bar.get_x() + bar.get_width(),  # Posición x (justo al lado de la barra)
                bar.get_y() + (height / 1 ),              # Posición y (centro vertical de la barra)
                f'{height}',                           # Etiqueta
                va='center',                           # Alineación vertical
                ha='left',                             # Alineación horizontal
                color='black',                         # Color de la etiqueta
                fontsize=12                            # Tamaño de la fuente
            )
    
    # Etiquetas del gráfico
    ax.set(xlabel='REPARTIDOR', ylabel='CANTIDAD FACTURAS', title=f'Cantidad de Facturas y Entregadas en el Año {year}')
    
    # Ajustar el diseño
    plt.tight_layout()
    
    # Mostrar el gráfico
    plt.legend()
    plt.show()

# %%
for year in years:
    plt.figure(figsize=(12,6))
    
    # Supongamos que tienes un DataFrame llamado df con las columnas 'codigo_repartidor', 'facturas_entregadas', 'facturas_totales'
    df_filtered = df[df['YEAR'] == year]
    
    # Agrupar los datos por 'codigo_repartidor' y calcular la suma de 'facturas_entregadas' y 'facturas_totales'
    facturas_por_repartidor = df_filtered.groupby('ID_REPARTIDOR')[['CANT_FACT_ENTREGA_TOTAL', 'CANT_FACT_TOTALES', 'CANT_FACT_ENTREGA_PARCIAL','CANT_FACT_ENTREGA_MOTIVOS']].sum().reset_index()

    # Convertir los datos al formato largo para que seaborn pueda entenderlos mejor
    facturas_long = pd.melt(facturas_por_repartidor, id_vars=['ID_REPARTIDOR'], value_vars=['CANT_FACT_ENTREGA_TOTAL', 'CANT_FACT_TOTALES', 'CANT_FACT_ENTREGA_PARCIAL','CANT_FACT_ENTREGA_MOTIVOS'],
                            var_name='cantidad', value_name='tipo_factura')

    # Crear el gráfico de barras
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x='ID_REPARTIDOR', y='tipo_factura', hue='cantidad', data=facturas_long)

    # Personalizar el gráfico
    ax.set(xlabel='Código de Repartidor', ylabel='Cantidad', title=f'Cantidad de Facturas y Entregadas en el Año {year}')
    

    # Añadir etiquetas a las barras
    for container in ax.containers:
        ax.bar_label(container, size=10)

    # Ajustar el layout
    plt.tight_layout()
    plt.xticks(rotation=45)

    # Mostrar el gráfico
    plt.show()

# %%
df.describe().T
# Out:
#                              count                           mean  \
# ID_VISITA                  48685.0            1862061511215558.75
# ID_REPARTIDOR              48685.0                       4.355222
# NUMERO_HOJA_REPARTO        48685.0                   98354.073164
# FECHA_INICIO                 48685  2022-06-20 06:20:02.785252352
# HORA_INICIO                48685.0                  136345.843977
# DURACION                   48685.0                      32.614317
# CANT_FACT_TOTALES          48685.0                       1.363007
# CANT_FACT_ENTREGA_TOTAL    48685.0                       1.020088
# CANT_FACT_ENTREGA_PARCIAL  48685.0                       0.003882
# CANT_FACT_ENTREGA_MOTIVOS  48685.0                       0.339037
# CANT_ITEMS_TOTALES         48685.0                      86.586176
# CANT_ITEMS_ENTREGADOS      48685.0                       69.37377
# CANT_ITEMS_NO_ENTREGADOS   48685.0                      17.212406
# CANT_COB_FACT_TOTALES      48685.0                       1.237506
# CANT_COB_FACT_COBRADAS     48685.0                       0.802855
# CANT_COB_FACT_NO_COBRADAS  48685.0                       0.434651
# MONTO_TOTAL_DEUDA          48685.0                   10390.646906
# MONTO_COBRADO              48685.0                    3652.169598
# A_CREDITO                  48358.0                        0.48722
# GPS_LATITUD                48685.0                     -20.922873
# GPS_LONGITUD               48685.0                     -42.831389
# GPS_PRECISION              48685.0                       6.920096
# YEAR                       48685.0                    2021.892513
#
#                                            min                  25%  \
# ID_VISITA                    120210923083707.0    320220413163230.0
# ID_REPARTIDOR                              1.0                  1.0
# NUMERO_HOJA_REPARTO                    65994.0              97302.0
# FECHA_INICIO               2018-09-18 00:00:00  2022-05-10 00:00:00
# HORA_INICIO                                4.0             101654.0
# DURACION                              -86221.0                  0.0
# CANT_FACT_TOTALES                          0.0                  1.0
# CANT_FACT_ENTREGA_TOTAL                    0.0                  0.0
# CANT_FACT_ENTREGA_PARCIAL                  0.0                  0.0
# CANT_FACT_ENTREGA_MOTIVOS                  0.0                  0.0
# CANT_ITEMS_TOTALES                         0.0                 14.0
# CANT_ITEMS_ENTREGADOS                      0.0                  0.0
# CANT_ITEMS_NO_ENTREGADOS                   0.0                  0.0
# CANT_COB_FACT_TOTALES                      0.0                  1.0
# CANT_COB_FACT_COBRADAS                     0.0                  0.0
# CANT_COB_FACT_NO_COBRADAS                 -1.0                  0.0
# MONTO_TOTAL_DEUDA                          0.0              2404.27
# MONTO_COBRADO                              0.0                  0.0
# A_CREDITO                                  0.0                  0.0
# GPS_LATITUD                         -31.523066           -31.396936
# GPS_LONGITUD                        -64.501693            -64.23772
# GPS_PRECISION                              0.0             1.448648
# YEAR                                    2018.0               2022.0
#
#                                            50%                  75%  \
# ID_VISITA                    620220413152054.0   1020220923100540.0
# ID_REPARTIDOR                              4.0                  6.0
# NUMERO_HOJA_REPARTO                    99071.0             100912.0
# FECHA_INICIO               2022-07-20 00:00:00  2022-10-07 00:00:00
# HORA_INICIO                           134709.0             173245.0
# DURACION                                   0.0                  8.0
# CANT_FACT_TOTALES                          1.0                  2.0
# CANT_FACT_ENTREGA_TOTAL                    1.0                  1.0
# CANT_FACT_ENTREGA_PARCIAL                  0.0                  0.0
# CANT_FACT_ENTREGA_MOTIVOS                  0.0                  1.0
# CANT_ITEMS_TOTALES                        37.0                 88.0
# CANT_ITEMS_ENTREGADOS                     22.0                 68.0
# CANT_ITEMS_NO_ENTREGADOS                   0.0                  0.0
# CANT_COB_FACT_TOTALES                      1.0                  1.0
# CANT_COB_FACT_COBRADAS                     1.0                  1.0
# CANT_COB_FACT_NO_COBRADAS                  0.0                  1.0
# MONTO_TOTAL_DEUDA                      5304.42             11271.36
# MONTO_COBRADO                              0.0              4774.33
# A_CREDITO                                  0.0                  1.0
# GPS_LATITUD                         -31.349472                  0.0
# GPS_LONGITUD                        -64.208111                  0.0
# GPS_PRECISION                              2.6                7.504
# YEAR                                    2022.0               2022.0
#
#                                             max                 std
# ID_VISITA                  102022112409102304.0  7307521216379250.0
# ID_REPARTIDOR                              10.0            3.186642
# NUMERO_HOJA_REPARTO                    103262.0         5195.291934
# FECHA_INICIO                2023-01-17 00:00:00                 NaN
# HORA_INICIO                            235934.0        53391.057318
# DURACION                                44936.0          726.066933
# CANT_FACT_TOTALES                          27.0             0.76608
# CANT_FACT_ENTREGA_TOTAL                    27.0            0.904829
# CANT_FACT_ENTREGA_PARCIAL                   2.0            0.062516
# CANT_FACT_ENTREGA_MOTIVOS                  10.0            0.677949
# CANT_ITEMS_TOTALES                       9553.0          202.402796
# CANT_ITEMS_ENTREGADOS                    9553.0          192.137115
# CANT_ITEMS_NO_ENTREGADOS                 5133.0           80.132613
# CANT_COB_FACT_TOTALES                      27.0             0.94006
# CANT_COB_FACT_COBRADAS                     15.0            0.793271
# CANT_COB_FACT_NO_COBRADAS                  27.0            0.953518
# MONTO_TOTAL_DEUDA                    1264982.46        20465.987029
# MONTO_COBRADO                         264559.35         7604.779749
# A_CREDITO                                   1.0            0.499842
# GPS_LATITUD                                 0.0           14.791239
# GPS_LONGITUD                                0.0           30.279226
# GPS_PRECISION                        961.180725           19.413559
# YEAR                                     2023.0            0.633379

# %%
sns.distplot(df['CANT_ITEMS_TOTALES']) # en próximas versiones esta función será deprecad
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27472\1060909327.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CANT_ITEMS_TOTALES']) # en próximas versiones esta función será deprecad
# <Axes: xlabel='CANT_ITEMS_TOTALES', ylabel='Density'>

# %%
df_corr = df.select_dtypes(include=['int64','float64'])

correlation_matrix = df_corr.corr()
# Establecer un umbral para considerar una correlación como fuerte
plt.figure(figsize=(20,6))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',vmin=-1,vmax=1)
plt.title('Mapa de calor de correlacion')
plt.show()
threshold = 0.6

# Encontrar pares de columnas con correlación fuerte
strong_correlations = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname1 = correlation_matrix.columns[i]
            colname2 = correlation_matrix.columns[j]
            correlation_value = correlation_matrix.iloc[i, j]
            strong_correlations.append((colname1, colname2, correlation_value))

# Imprimir los resultados
print("Pares de columnas con correlación fuerte:")
for col1, col2, corr in strong_correlations:
    print(f"{col1} y {col2}: {corr:.2f}")
# Out:
# Pares de columnas con correlación fuerte:
# CANT_FACT_ENTREGA_TOTAL y CANT_FACT_TOTALES: 0.68
# CANT_ITEMS_ENTREGADOS y CANT_ITEMS_TOTALES: 0.92
# CANT_COB_FACT_TOTALES y CANT_FACT_TOTALES: 0.75
# CANT_COB_FACT_TOTALES y CANT_FACT_ENTREGA_TOTAL: 0.64
# CANT_COB_FACT_NO_COBRADAS y CANT_COB_FACT_TOTALES: 0.65
# MONTO_TOTAL_DEUDA y CANT_ITEMS_TOTALES: 0.67
# MONTO_TOTAL_DEUDA y CANT_ITEMS_ENTREGADOS: 0.62
# GPS_LONGITUD y GPS_LATITUD: 1.00

# %%
#df.info()
df_sin_hoja = df.drop(['ID_HOJA_REPARTO','FECHA_INICIO','ID_VISITA','ID_CUENTA'],axis=1)
df_sin_hoja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48685 entries, 0 to 48684
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID_REPARTIDOR              48685 non-null  int64
#  1   NUMERO_HOJA_REPARTO        48685 non-null  int64
#  2   HORA_INICIO                48685 non-null  int64
#  3   DURACION                   48685 non-null  int64
#  4   CANT_FACT_TOTALES          48685 non-null  int64
#  5   CANT_FACT_ENTREGA_TOTAL    48685 non-null  int64
#  6   CANT_FACT_ENTREGA_PARCIAL  48685 non-null  int64
#  7   CANT_FACT_ENTREGA_MOTIVOS  48685 non-null  int64
#  8   CANT_ITEMS_TOTALES         48685 non-null  float64
#  9   CANT_ITEMS_ENTREGADOS      48685 non-null  float64
#  10  CANT_ITEMS_NO_ENTREGADOS   48685 non-null  float64
#  11  CANT_COB_FACT_TOTALES      48685 non-null  int64
#  12  CANT_COB_FACT_COBRADAS     48685 non-null  int64
#  13  CANT_COB_FACT_NO_COBRADAS  48685 non-null  int64
#  14  MONTO_TOTAL_DEUDA          48685 non-null  float64
#  15  MONTO_COBRADO              48685 non-null  float64
#  16  A_CREDITO                  48685 non-null  float64
#  17  GPS_LATITUD                48685 non-null  float64
#  18  GPS_LONGITUD               48685 non-null  float64
#  19  GPS_PRECISION              48685 non-null  float64
#  20  YEAR                       48685 non-null  int32
# dtypes: float64(9), int32(1), int64(11)
# memory usage: 7.6 MB

# %%
from sklearn.model_selection import train_test_split
df_sin_hoja = df.drop(['ID_HOJA_REPARTO','FECHA_INICIO','ID_VISITA','ID_CUENTA'],axis=1)
train_set,test_set = train_test_split(df_sin_hoja,test_size=0.2, random_state= 42)

# %%
X_train = train_set.drop('MONTO_COBRADO',axis=1)
y_train = train_set['MONTO_COBRADO'].copy()

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38948 entries, 31769 to 15795
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID_REPARTIDOR              38948 non-null  int64
#  1   NUMERO_HOJA_REPARTO        38948 non-null  int64
#  2   HORA_INICIO                38948 non-null  int64
#  3   DURACION                   38948 non-null  int64
#  4   CANT_FACT_TOTALES          38948 non-null  int64
#  5   CANT_FACT_ENTREGA_TOTAL    38948 non-null  int64
#  6   CANT_FACT_ENTREGA_PARCIAL  38948 non-null  int64
#  7   CANT_FACT_ENTREGA_MOTIVOS  38948 non-null  int64
#  8   CANT_ITEMS_TOTALES         38948 non-null  float64
#  9   CANT_ITEMS_ENTREGADOS      38948 non-null  float64
#  10  CANT_ITEMS_NO_ENTREGADOS   38948 non-null  float64
#  11  CANT_COB_FACT_TOTALES      38948 non-null  int64
#  12  CANT_COB_FACT_COBRADAS     38948 non-null  int64
#  13  CANT_COB_FACT_NO_COBRADAS  38948 non-null  int64
#  14  MONTO_TOTAL_DEUDA          38948 non-null  float64
#  15  A_CREDITO                  38948 non-null  float64
#  16  GPS_LATITUD                38948 non-null  float64
#  17  GPS_LONGITUD               38948 non-null  float64
#  18  GPS_PRECISION              38948 non-null  float64
#  19  YEAR                       38948 non-null  int32
# dtypes: float64(8), int32(1), int64(11)
# memory usage: 6.1 MB

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train) # Construcción/inferencia del modelo
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# Hago predecir el modelo generado sobre el conjunto de training
y_pred = lr_model.predict(X_train)

# 4. Evaluo la performance del modelo sobre el conjunto de training, mediante R2 y RMSE
r2 = r2_score(y_train, y_pred)
print("Train R2=", r2)
mse = mean_squared_error(y_train, y_pred)
print("Train RMSE=", np.sqrt(mse))
# Out:
# Train R2= 0.37723538616612307
# Train RMSE= 6037.753804628216

# %%
# Tomo las variables regresoras en X (y descarto 'quality' de ese dataframe)
X_test = test_set.drop('MONTO_COBRADO', axis=1)
# X_test = X_test[['fixed acidity', 'residual sugar', 'alcohol']]
# Tomo la variable a dependiente/a predecir
y_test = test_set['MONTO_COBRADO'].copy()

# Hago predecir el modelo generado sobre el conjunto de test
y_pred = lr_model.predict(X_test)

# 4. Evaluo la performance del modelo sobre el conjunto de test, mediante R2 y RMSE
r2 = r2_score(y_test, y_pred)
print("Test R2=", r2)
mse = mean_squared_error(y_test, y_pred)
print("Test RMSE=", np.sqrt(mse))
# Out:
# Test R2= 0.4453746374374399
# Test RMSE= 5523.6260960821155

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(lr_model)
visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
plt.show()
# Out:
# c:\Users\hp\Documents\Lucas\MundoE\hackathon_mE\mEvenv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
